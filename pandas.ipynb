# %%
#pandas

# %%
# !pip install pandas

# %%
# !pip install pandas numpy

# %%
import pandas as pd
import numpy as np

data = {"Name": ["Ankit", "Rahul","mukesh","sanju","printam","pankaj","niraj"], "Age": [21, 22,23,34,28,30,40],
       "salary":[1000,2000,3000,4000,5000,6000,7000]
       
       
       
       
       }

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  salary
# 0    Ankit   21    1000
# 1    Rahul   22    2000
# 2   mukesh   23    3000
# 3    sanju   34    4000
# 4  printam   28    5000
# 5   pankaj   30    6000
# 6    niraj   40    7000

# %%
df.head(3)
# Out:
#      Name  Age  salary
# 0   Ankit   21    1000
# 1   Rahul   22    2000
# 2  mukesh   23    3000

# %%
df.tail(2)
# Out:
#      Name  Age  salary
# 5  pankaj   30    6000
# 6   niraj   40    7000

# %%
df.columns
# Out:
# Index(['Name', 'Age'], dtype='str')

# %%
df.Age
# Out:
# 0    21
# 1    22
# 2    23
# 3    34
# 4    28
# 5    30
# 6    40
# Name: Age, dtype: int64

# %%
df.Name
# Out:
# 0      Ankit
# 1      Rahul
# 2     mukesh
# 3      sanju
# 4    printam
# 5     pankaj
# 6      niraj
# Name: Name, dtype: str

# %%
df.salary
# Out:
# 0    1000
# 1    2000
# 2    3000
# 3    4000
# 4    5000
# 5    6000
# 6    7000
# Name: salary, dtype: int64

# %%
df.salary.sum()
# Out:
# np.int64(28000)

# %%
df.salary.min()
# Out:
# np.int64(1000)

# %%
df.salary.max()
# Out:
# np.int64(7000)

# %%
df.salary.mean()
# Out:
# np.float64(4000.0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      str
#  1   Age     7 non-null      int64
#  2   salary  7 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 300.0 bytes

# %%
df.describe()
# Out:
#              Age       salary
# count   7.000000     7.000000
# mean   28.285714  4000.000000
# std     6.993194  2160.246899
# min    21.000000  1000.000000
# 25%    22.500000  2500.000000
# 50%    28.000000  4000.000000
# 75%    32.000000  5500.000000
# max    40.000000  7000.000000

# %%
df.shape
# Out:
# (7, 3)

# %%
data = {"Name": ["Ankit", np.nan,"mukesh",np.nan,"printam","pankaj","niraj"],
        "Age": [21, 22,23,np.nan,28,30,np.nan],
       "salary":[1000,np.nan,3000,4000,np.nan,6000,7000]
       }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age  salary
# 0    Ankit  21.0  1000.0
# 1      NaN  22.0     NaN
# 2   mukesh  23.0  3000.0
# 3      NaN   NaN  4000.0
# 4  printam  28.0     NaN
# 5   pankaj  30.0  6000.0
# 6    niraj   NaN  7000.0

# %%
df.isnull()
# Out:
#     Name    Age  salary
# 0  False  False   False
# 1   True  False    True
# 2  False  False   False
# 3   True   True   False
# 4  False  False    True
# 5  False  False   False
# 6  False   True   False

# %%
df.isnull().sum()
# Out:
# Name      2
# Age       2
# salary    2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(6)

# %%
print(df.isnull().sum().sum())
# Out:
# 6

# %%
# remove all null values
df.dropna()
# Out:
#      Name   Age  salary
# 0   Ankit  21.0  1000.0
# 2  mukesh  23.0  3000.0
# 5  pankaj  30.0  6000.0

# %%
#replace missing value witha dummy value
df.fillna(value="missing")
# Out:
#       Name      Age   salary
# 0    Ankit     21.0   1000.0
# 1  missing     22.0  missing
# 2   mukesh     23.0   3000.0
# 3  missing  missing   4000.0
# 4  printam     28.0  missing
# 5   pankaj     30.0   6000.0
# 6    niraj  missing   7000.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      float64
#  2   salary  5 non-null      float64
# dtypes: float64(2), str(1)
# memory usage: 300.0 bytes

# %%
newdf = df.copy()

# %%
newdf
# Out:
#       Name      Age   salary
# 0    Ankit     21.0   1000.0
# 1  missing     22.0  missing
# 2   mukesh     23.0   3000.0
# 3  missing  missing   4000.0
# 4  printam     28.0  missing
# 5   pankaj     30.0   6000.0
# 6    niraj  missing   7000.0

# %%
df['Name'] = df['Age'].fillna('missing')

# %%
df
# Out:
#       Name   Age  salary
# 0     21.0  21.0  1000.0
# 1     22.0  22.0  4200.0
# 2     23.0  23.0  3000.0
# 3  missing   NaN  4000.0
# 4     28.0  28.0  4200.0
# 5     30.0  30.0  6000.0
# 6  missing   NaN  7000.0

# %%
df['salary'] = df['salary'].fillna(value = df['salary'].mean())

# %%
df
# Out:
#       Name   Age  salary
# 0     21.0  21.0  1000.0
# 1     22.0  22.0  4200.0
# 2     23.0  23.0  3000.0
# 3  missing   NaN  4000.0
# 4     28.0  28.0  4200.0
# 5     30.0  30.0  6000.0
# 6  missing   NaN  7000.0
