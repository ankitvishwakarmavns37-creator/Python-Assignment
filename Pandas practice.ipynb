# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data=pd.read_excel("C:Users/Om/Downloads/Financial_Sample.xlsx")

# %%
data.shape
# Out:
# (700, 16)

# %%
data.head(5)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3        20.0      32370.0        0.0  32370.0  16185.0
# 1                    3        20.0      26420.0        0.0  26420.0  13210.0
# 2                    3        15.0      32670.0        0.0  32670.0  21780.0
# 3                    3        15.0      13320.0        0.0  13320.0   8880.0
# 4                    3        15.0      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
data.tail(5)
# Out:
#               Segment                   Country   Product Discount Band  \
# 695    Small Business                    France  Amarilla          High
# 696    Small Business                    Mexico  Amarilla          High
# 697        Government                    Mexico   Montana          High
# 698        Government                    Canada     Paseo          High
# 699  Channel Partners  United States of America       VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 695      2475.0                  260       300.0     742500.0  111375.00
# 696       546.0                  260       300.0     163800.0   24570.00
# 697      1368.0                    5         7.0       9576.0    1436.40
# 698       723.0                   10         7.0       5061.0     759.15
# 699      1806.0                  250        12.0      21672.0    3250.80
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year
# ...

# %%
data.isnull()
# Out:
#      Segment  Country  Product  Discount Band  Units Sold  \
# 0      False    False    False           True       False
# 1      False    False    False           True       False
# 2      False    False    False           True       False
# 3      False    False    False           True       False
# 4      False    False    False           True       False
# ..       ...      ...      ...            ...         ...
# 695    False    False    False          False       False
# 696    False    False    False          False       False
# 697    False    False    False          False       False
# 698    False    False    False          False       False
# 699    False    False    False          False       False
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts   Sales   COGS  \
# 0                  False       False        False      False   False  False
# 1                  False       False        False      False   False  False
# ...

# %%
data.isnull().sum()
# Out:
# Segment                 8
# Country                11
# Product                 8
# Discount Band          62
# Units Sold              5
# Manufacturing Price     0
# Sale Price              7
# Gross Sales             5
# Discounts               5
#  Sales                  0
# COGS                    0
# Profit                  0
# Date                    0
# Month Number            0
# Month Name              0
# Year                    0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(111)

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn  as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.figure(figsize=(8,3))
sns.heatmap(data.isnull())
plt.show()

# %%
data.describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   695.000000           700.000000  693.000000  6.950000e+02
# mean   1607.880576            96.477143  117.914863  1.839670e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     906.500000             5.000000   12.000000  1.760250e+04
# 50%    1540.000000            10.000000   20.000000  3.838500e+04
# 75%    2224.750000           250.000000  300.000000  2.859500e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
# std     867.307497           108.602612  136.571680  2.547749e+05
#
#            Discounts         Sales           COGS         Profit  \
# count     695.000000  7.000000e+02     700.000000     700.000000
# mean    13077.162345  1.696091e+05  145475.211429   24133.860371
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# 25%       799.640000  1.592800e+04    7490.000000    2805.960000
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              692 non-null    str
#  1   Country              689 non-null    str
#  2   Product              692 non-null    str
#  3   Discount Band        638 non-null    str
#  4   Units Sold           695 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           693 non-null    float64
#  7   Gross Sales          695 non-null    float64
#  8   Discounts            695 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[us]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    str
# ...

# %%
#pivote (summary table)groupby
data.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='str')

# %%
data.Country.unique()
# Out:
# <StringArray>
# ['Canada', 'Germany', 'France', 'Mexico', 'United States of America', nan]
# Length: 6, dtype: str

# %%
data.Country.value_counts()
# Out:
# Country
# France                      139
# Mexico                      138
# United States of America    138
# Canada                      137
# Germany                     137
# Name: count, dtype: int64

# %%
data.groupby("Country")["Profit"].sum()
# Out:
# Country
# Canada                      3359437.935
# France                      3781020.780
# Germany                     3624167.730
# Mexico                      2889313.870
# United States of America    2723336.745
# Name: Profit, dtype: float64

# %%
data.groupby("Country").agg({"Profit" :"sum"})
# Out:
#                                Profit
# Country
# Canada                    3359437.935
# France                    3781020.780
# Germany                   3624167.730
# Mexico                    2889313.870
# United States of America  2723336.745

# %%
data.groupby("Country").agg({"Profit" :"sum"}).reset_index()
# Out:
#                     Country       Profit
# 0                    Canada  3359437.935
# 1                    France  3781020.780
# 2                   Germany  3624167.730
# 3                    Mexico  2889313.870
# 4  United States of America  2723336.745

# %%
pbc=data.groupby("Country").agg({"Profit" :"sum"}).reset_index()
pbc
# Out:
#                     Country       Profit
# 0                    Canada  3359437.935
# 1                    France  3781020.780
# 2                   Germany  3624167.730
# 3                    Mexico  2889313.870
# 4  United States of America  2723336.745

# %%
pbc["Profit %Age"]=pbc["Profit"]
pbc
# Out:
#                     Country       Profit  Profit %Age
# 0                    Canada  3359437.935  3359437.935
# 1                    France  3781020.780  3781020.780
# 2                   Germany  3624167.730  3624167.730
# 3                    Mexico  2889313.870  2889313.870
# 4  United States of America  2723336.745  2723336.745

# %%
pbc["Profit %Age"]=pbc["Profit"].map(lambda val:val/pbc["Profit"].sum()*100)
pbc
# Out:
#                     Country       Profit  Profit %Age
# 0                    Canada  3359437.935    20.512799
# 1                    France  3781020.780    23.086993
# 2                   Germany  3624167.730    22.129245
# 3                    Mexico  2889313.870    17.642212
# 4  United States of America  2723336.745    16.628752

# %%
pbc["Profit %Age"]=pbc["Profit"].map(lambda val:round(val/pbc["Profit"].sum()*100,2))
pbc
# Out:
#                     Country       Profit  Profit %Age
# 0                    Canada  3359437.935        20.51
# 1                    France  3781020.780        23.09
# 2                   Germany  3624167.730        22.13
# 3                    Mexico  2889313.870        17.64
# 4  United States of America  2723336.745        16.63

# %%
data.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='str')

# %%
data["Segment"].unique()
# Out:
# <StringArray>
# [      'Government',        'Midmarket', 'Channel Partners',
#        'Enterprise',   'Small Business',                nan]
# Length: 6, dtype: str

# %%
data["Segment"].count()
# Out:
# np.int64(692)

# %%
data["Segment"].value_counts()
# Out:
# Segment
# Government          294
# Midmarket           100
# Enterprise          100
# Small Business      100
# Channel Partners     98
# Name: count, dtype: int64

# %%
data.groupby('Segment')[' Sales'].sum()
# Out:
# Segment
# Channel Partners    1.765773e+06
# Enterprise          1.961169e+07
# Government          5.188648e+07
# Midmarket           2.381883e+06
# Small Business      4.242792e+07
# Name:  Sales, dtype: float64

# %%
data.groupby('Segment').agg({' Sales':'sum'})
# Out:
#                          Sales
# Segment
# Channel Partners  1.765773e+06
# Enterprise        1.961169e+07
# Government        5.188648e+07
# Midmarket         2.381883e+06
# Small Business    4.242792e+07

# %%
data.groupby('Segment').agg({' Sales':'sum'}).reset_index()
# Out:
#             Segment         Sales
# 0  Channel Partners  1.765773e+06
# 1        Enterprise  1.961169e+07
# 2        Government  5.188648e+07
# 3         Midmarket  2.381883e+06
# 4    Small Business  4.242792e+07

# %%
data.groupby('Segment').agg({' Sales':'mean'}).reset_index()
# Out:
#             Segment          Sales
# 0  Channel Partners   18018.089388
# 1        Enterprise  196116.943750
# 2        Government  176484.624456
# 3         Midmarket   23818.830750
# 4    Small Business  424279.185000
