# %% [markdown]
# # D. Python ELIF (Multiple Conditions)

# %% [markdown]
# # 31. Print day name using day number (1–7)

# %%
day=int(input("enter day number(1-7):"))
if day==1:
    print("monday")
elif day==2:
    print("tuesday")
elif day==3:
    print("wednesday")
elif day==4:
    print("thursday")
elif day==5:
    print("friday")
elif day==6:
    print("saturday")
elif day==7:
    print("sunday")
else:
    print("invalid day number")
# Out:
# enter day number(1-7): 3
# wednesday

# %% [markdown]
# # 32. Print month name using month number

# %%
month=int(input("enter month number(1-12):"))
if month==1:
    print("jan")
elif month==2:
    print("feb")
elif month==3:
    print("mar")
elif month==4:
    print("apr")
elif month==5:
    print("may")
elif month==6:
    print("june")
elif month==7:
    print("july")
elif month==8:
    print("aug")
elif month==9:
    print("sept")
elif month==10:
    print("oct")
elif month==11:
    print("nov")
elif month==12:
    print("dec")
else:
    print("envalid month number")
# Out:
# enter month number(1-12): 8
# aug

# %% [markdown]
# # 33. Display grade based on percentage

# %%
per=float(input("enter the number"))
if per>=90:
    print("grade: A")
elif per>=75:
    print("grade: B")
elif per>=50:
    print("grade: C")
elif per<35:
    print("Fail")
else:
    print("invalid per")
# Out:
# enter the number 84
# grade: B

# %% [markdown]
# # 34. Display bonus percentage based on experience years

# %%
exp=float(input("enter the year of experience:"))
if exp<=1:
    print("per:0%")
elif exp<=3:
    print("per:5%")
elif exp<=6:
    print("per:10%")
elif exp<=10:
    print("per:15%")
else:
    print("per:20%")
# Out:
# enter the year of experience: 7
# per:15%

# %% [markdown]
# # 35. Categorize temperature as Cold / Warm / Hot

# %%
temp=int(input("enter the temp"))
if temp<20:
    print("cold")
elif temp<30:
    print("warm")
elif temp<40:
    print("hot")
else:
    print("normal temp")
# Out:
# enter the temp 39
# hot

# %% [markdown]
# # 36. Categorize employee based on salary range

# %%
salary=int(input("enter the salary"))
if salary>5000:
    print("high salary")
elif salary<3000:
    print("medium salary")
else:
    print("low salary")
# Out:
# enter the salary 4000
# low salary

# %% [markdown]
# # 37. Print discount percentage based on purchase amount

# %%
amount=int(input("enter the amount"))
if amount<1000:
    print("discount:5%")
elif amount<5000:
    print("discount: 10%")
else:
    print("discount: 15%")
# Out:
# enter the amount 6767
# discount: 15%

# %% [markdown]
# # 38. Identify number type: single-digit / double-digit / multi-digit

# %%
num = int(input("Enter a number: "))

if -9 <= num <= 9:
    print("Single-digit number")
elif -99 <= num <= 99:
    print("Double-digit number")
else:
    print("Multi-digit number")
# Out:
# Enter a number:  2344
# Multi-digit number

# %% [markdown]
# # 39. Assign performance rating: Poor / Average / Good / Excellent

# %%
num=int(input("enter the performance number"))
if num<40:
    print("poor number")
elif num<60:
    print("average number")
elif num<80:
    print("good number")
else:
    print("excellent number")
# Out:
# enter the performance number 8988
# excellent number

# %% [markdown]
# # E. Python COMPLEX CONDITIONS (AND / OR / NOT)

# %% [markdown]
# # 40. Check whether a number is divisible by 5 and 11

# %%
num=int(input("enter the number"))
if num%5==0 and num%11==0:
    print("both number is divided by 5 and 11")
else:
     print("both number is not divided by 5 and 11")
# Out:
# enter the number 11
# both number is not divided by 5 and 11

# %% [markdown]
# # 41. Check if a person is eligible for loan

# %%
age=int(input("enter the age"))
salary=int(input("enter the salary"))
score=int(input("enter the score"))
if age>=18 & (salary>=50000) & (score>=800):
    print("Eligible person")
else:
    print("person is not eligible")
# Out:
# enter the age 19
# enter the salary 65444
# enter the score 1000
# Eligible person

# %% [markdown]
# # 42. Validate login using username AND password

# %%
username=input("enter  username")
password=input("enter password")

if username == "ankit" and password == "9936" :
    print("loggin succesful")
else:
    print("incorrect username or password")
# Out:
# enter  username ankit
# enter password 9936
# loggin succesful

# %% [markdown]
# # 43. Check student pass condition

# %%
sub1=int(input("enter subject marks:1"))
sub2=int(input("enter subject marks:2"))
sub3=int(input("enter subject marks:3"))

aveg=(sub1+sub2+sub3)/3

if sub1>=40 and sub2>=40 and sub3>=40 and aveg>=50:
    print(" student pass")
else:
    print("student fail")
# Out:
# enter subject marks:1 50
# enter subject marks:2 50
# enter subject marks:3 50
#  student pass

# %% [markdown]
# # 44. Check if a number lies between 10 and 100

# %%
num=int(input("enter the number"))
if num>=10 and num<=100:
    print("number lies between 10 to 100")
else:
    print("number lies is not between 10 to 100")
# Out:
# enter the number 34
# number lies between 10 to 100

# %% [markdown]
# # 45. Check exam eligibility

# %%
atten=int(input("enter the atten number"))
medi=input("entre the medi (yes/no):")
if atten>=75 or medi=="yes":
    print("Eligible for Exam")
else:
    print("Not Eligible for exam")
# Out:
# enter the atten number 34
# entre the medi (yes/no): rt
# Not Eligible for exam

# %% [markdown]
# # 46. Check whether an email format is valid

# %%
email=input("enter the email")
if "@" in email and "." in email:
    print("Valid email")
else:
    print("Invalid email")
# Out:
# enter the email jgiug
# Invalid email

# %% [markdown]
# # 47. Determine insurance eligibility using age, health status, and income

# %%
age=int(input("enter the age"))
health=input("enter the health(good/bad):")
income=int(input("inter the income"))
if (age>=18 and age<=60) and (health=="good") and (income>=30000):
    print("insurence eligible")
else:
    print("insurence is not eligible")
# Out:
# enter the age 12
# enter the health(good/bad): sfg
# inter the income 3534
# insurence is not eligible

# %% [markdown]
# # 48. Check leap year using complete leap year logic

# %%
year=int(input("enter the year"))
if (year%400==0) or (year%4==0 and year%100!=0):
    print("leap year")
else:
    print("not leap year")
# Out:
# enter the year 12
# leap year
